# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Temperature_Forecasting_MethodComparison/blob/main/GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import plotly
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)


df = pd.read_csv("/content/Athens_meteo.csv",
                 parse_dates=['DAY'],  # change to date time format
                 index_col="DAY")

df = df[['T_mean', 'RH_max', 'RH_mean', 'RH_min', 'P_max','P_mean', 'P_min', 'Rain', 'U', 'U_max']]

df.head()
# Out:
#             T_mean  RH_max  RH_mean  RH_min    P_max   P_mean    P_min  Rain  \
# DAY
# 2010-01-01  18.100  61.400       91      33 1003.600 1006.300 1002.000 0.200
# 2010-01-02  15.700  57.400       70      45 1005.200 1008.700 1001.500 0.000
# 2010-01-03  13.600  56.000       76      39 1011.700 1016.700 1008.600 0.000
# 2010-01-04   9.600  50.700       60      38 1021.300 1023.100 1016.800 0.000
# 2010-01-05  13.500  70.500       82      54 1018.700 1022.100 1015.500 0.000
#
#                U  U_max
# DAY
# 2010-01-01 4.000 12.700
# 2010-01-02 6.800 20.700
# 2010-01-03 5.000 15.400
# 2010-01-04 4.300 11.000
# 2010-01-05 7.900 19.800

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# ─────────────────────────────────────────────────────────────
# Step 1: Add seasonal features
df['dayofyear'] = df.index.dayofyear
df['sin_doy'] = np.sin(2 * np.pi * df['dayofyear'] / 365.0)
df['cos_doy'] = np.cos(2 * np.pi * df['dayofyear'] / 365.0)

# Step 2: Feature selection
features = ['T_mean', 'RH_mean', 'P_mean', 'sin_doy', 'cos_doy']
target = 'T_mean'
window = 30

# Step 3: Prepare full feature and target arrays
X_full = df[features].values
y_full = df[[target]].values

# Step 4: Chronological train/test split (80%/20%)
split_index = int(len(df) * 0.8)
X_train_raw = X_full[:split_index]
X_test_raw = X_full[split_index:]
y_train_raw = y_full[:split_index]
y_test_raw = y_full[split_index:]

# Step 5: Scale features and target using only training data
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train_raw)
X_test_scaled = scaler_X.transform(X_test_raw)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_raw)
y_test_scaled = scaler_y.transform(y_test_raw)

# Step 6: Create time series sequences
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(len(X) - window_size):
        X_seq.append(X[i:i + window_size])
        y_seq.append(y[i + window_size])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, window)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, window)

# ─────────────────────────────────────────────────────────────
# Step 7: Build GRU model
model = Sequential([
    GRU(128, return_sequences=True, input_shape=(window, len(features))),
    Dropout(0.3),
    GRU(64),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(
    loss='mean_squared_error',
    optimizer=Adam(learning_rate=0.001),
    metrics=['mae']
)

# Step 7.5: Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-5)

# Step 8: Train model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_split=0.1,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ─────────────────────────────────────────────────────────────
# Step 9: Evaluate model on test set
y_pred_scaled = model.predict(X_test_seq)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_seq)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print("="*40)
print(" Model Evaluation on Test Set")
print("="*40)
print(f"MAE       : {mae:.2f} °C")
print(f"RMSE      : {rmse:.2f} °C")
print(f"R² Score  : {r2:.3f}")
print("="*40)

# Step 10: Reconstruct aligned test dates after sequence window
test_index_start = split_index + window
aligned_test_index = df.index[test_index_start:test_index_start + len(y_test_seq)]

# Create DataFrame with predictions
df_preds = pd.DataFrame({
    'Date': aligned_test_index,
    'Actual': y_true.flatten(),
    'Predicted': y_pred.flatten()
}).set_index('Date')

# Step 11: Plot predictions
plt.figure(figsize=(12, 6))
plt.plot(df_preds.index, df_preds['Actual'], label='Actual')
plt.plot(df_preds.index, df_preds['Predicted'], label='Predicted')
plt.title('T_mean Prediction on Test Set (GRU)')
plt.ylabel('Temperature (°C)')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
print("="*40)

# Step 12: Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - loss: 0.1966 - mae: 0.3330 - val_loss: 0.0696 - val_mae: 0.2012 - learning_rate: 0.0010
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 0.0907 - mae: 0.2317 - val_loss: 0.0563 - val_mae: 0.1804 - learning_rate: 0.0010
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0708 - mae: 0.2062 - val_loss: 0.0519 - val_mae: 0.1730 - learning_rate: 0.0010
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 0.0645 - mae: 0.1949 - val_loss: 0.0447 - val_mae: 0.1625 - learning_rate: 0.0010
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 0.0639 - mae: 0.1931 - val_loss: 0.0418 - val_mae: 0.1507 - learning_rate: 0.0010
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 0.0526 - mae: 0.1729 - val_loss: 0.0393 - val_mae: 0.1503 - learning_rate: 0.0010
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.0474 - mae: 0.1662 - val_loss: 0.0424 - val_mae: 0.1492 - learning_rate: 0.0010
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 0.0542 - mae: 0.1760 - val_loss: 0.0414 - val_mae: 0.1468 - learning_rate: 0.0010
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0463 - mae: 0.1646 - val_loss: 0.0415 - val_mae: 0.1576 - learning_rate: 0.0010
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0504 - mae: 0.1721 - val_loss: 0.0362 - val_mae: 0.1444 - learning_rate: 0.0010
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 0.0503 - mae: 0.1722 - val_loss: 0.0368 - val_mae: 0.1449 - learning_rate: 0.0010
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.0450 - mae: 0.1630 - val_loss: 0.0360 - val_mae: 0.1415 - learning_rate: 0.0010
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - loss: 0.0496 - mae: 0.1665 - val_loss: 0.0377 - val_mae: 0.1497 - learning_rate: 0.0010
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 0.0499 - mae: 0.1724 - val_loss: 0.0363 - val_mae: 0.1444 - learning_rate: 0.0010
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 0.0447 - mae: 0.1617 - val_loss: 0.0427 - val_mae: 0.1582 - learning_rate: 0.0010
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0483 - mae: 0.1653 - val_loss: 0.0488 - val_mae: 0.1725 - learning_rate: 0.0010
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - loss: 0.0556 - mae: 0.1800 - val_loss: 0.0377 - val_mae: 0.1473 - learning_rate: 0.0010
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0436 - mae: 0.1610 - val_loss: 0.0366 - val_mae: 0.1385 - learning_rate: 5.0000e-04
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0433 - mae: 0.1604 - val_loss: 0.0365 - val_mae: 0.1434 - learning_rate: 5.0000e-04
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0404 - mae: 0.1524 - val_loss: 0.0403 - val_mae: 0.1538 - learning_rate: 5.0000e-04
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.0433 - mae: 0.1575 - val_loss: 0.0375 - val_mae: 0.1452 - learning_rate: 5.0000e-04
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - loss: 0.0438 - mae: 0.1579 - val_loss: 0.0347 - val_mae: 0.1386 - learning_rate: 5.0000e-04
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 0.0411 - mae: 0.1568 - val_loss: 0.0349 - val_mae: 0.1377 - learning_rate: 5.0000e-04
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0411 - mae: 0.1541 - val_loss: 0.0383 - val_mae: 0.1484 - learning_rate: 5.0000e-04
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0443 - mae: 0.1604 - val_loss: 0.0409 - val_mae: 0.1567 - learning_rate: 5.0000e-04
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0421 - mae: 0.1568 - val_loss: 0.0356 - val_mae: 0.1439 - learning_rate: 5.0000e-04
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.0428 - mae: 0.1580 - val_loss: 0.0390 - val_mae: 0.1477 - learning_rate: 5.0000e-04
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.0419 - mae: 0.1577 - val_loss: 0.0367 - val_mae: 0.1459 - learning_rate: 2.5000e-04
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 0.0402 - mae: 0.1540 - val_loss: 0.0360 - val_mae: 0.1425 - learning_rate: 2.5000e-04
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 0.0423 - mae: 0.1573 - val_loss: 0.0380 - val_mae: 0.1485 - learning_rate: 2.5000e-04
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 0.0381 - mae: 0.1472 - val_loss: 0.0354 - val_mae: 0.1419 - learning_rate: 2.5000e-04
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0446 - mae: 0.1574 - val_loss: 0.0381 - val_mae: 0.1470 - learning_rate: 2.5000e-04
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# ========================================
#  Model Evaluation on Test Set
# ========================================
# MAE       : 0.99 °C
# RMSE      : 1.33 °C
# R² Score  : 0.966
# ========================================
# ========================================
