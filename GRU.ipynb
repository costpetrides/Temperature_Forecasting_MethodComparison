# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Temperature_Forecasting_MethodComparison/blob/main/GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import plotly
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)


df = pd.read_csv("/content/Athens_meteo.csv",
                 parse_dates=['DAY'],  # change to date time format
                 index_col="DAY")

df = df[['T_mean', 'RH_max', 'RH_mean', 'RH_min', 'P_max','P_mean', 'P_min', 'Rain', 'U', 'U_max']]

df.head()
# Out:
#             T_mean  RH_max  RH_mean  RH_min    P_max   P_mean    P_min  Rain  \
# DAY
# 2010-01-01  18.100  61.400       91      33 1003.600 1006.300 1002.000 0.200
# 2010-01-02  15.700  57.400       70      45 1005.200 1008.700 1001.500 0.000
# 2010-01-03  13.600  56.000       76      39 1011.700 1016.700 1008.600 0.000
# 2010-01-04   9.600  50.700       60      38 1021.300 1023.100 1016.800 0.000
# 2010-01-05  13.500  70.500       82      54 1018.700 1022.100 1015.500 0.000
#
#                U  U_max
# DAY
# 2010-01-01 4.000 12.700
# 2010-01-02 6.800 20.700
# 2010-01-03 5.000 15.400
# 2010-01-04 4.300 11.000
# 2010-01-05 7.900 19.800

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# ─────────────────────────────────────────────────────────────
# Step 1: Add seasonal features
df['dayofyear'] = df.index.dayofyear
df['sin_doy'] = np.sin(2 * np.pi * df['dayofyear'] / 365.0)
df['cos_doy'] = np.cos(2 * np.pi * df['dayofyear'] / 365.0)

# Step 2: Feature selection
features = ['T_mean', 'RH_mean', 'P_mean', 'Rain', 'U', 'sin_doy', 'cos_doy']
target = 'T_mean'
window = 14

# Step 3: Prepare full feature and target arrays
X_full = df[features].values
y_full = df[[target]].values

# Step 4: Chronological train/test split (80%/20%)
split_index = int(len(df) * 0.8)
X_train_raw = X_full[:split_index]
X_test_raw = X_full[split_index:]
y_train_raw = y_full[:split_index]
y_test_raw = y_full[split_index:]

# Step 5: Scale features and target using only training data
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train_raw)
X_test_scaled = scaler_X.transform(X_test_raw)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_raw)
y_test_scaled = scaler_y.transform(y_test_raw)

# Step 6: Create time series sequences
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(len(X) - window_size):
        X_seq.append(X[i:i + window_size])
        y_seq.append(y[i + window_size])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, window)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, window)

# ─────────────────────────────────────────────────────────────
# Step 7: Build GRU model
model = Sequential([
    GRU(128, return_sequences=True, input_shape=(window, len(features))),
    Dropout(0.3),
    GRU(64),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(
    loss='mean_squared_error',
    optimizer=Adam(learning_rate=0.001),
    metrics=['mae']
)

# Step 7.5: Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-5)

# Step 8: Train model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_split=0.1,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ─────────────────────────────────────────────────────────────
# Step 9: Evaluate model on test set
y_pred_scaled = model.predict(X_test_seq)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_seq)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print("="*40)
print(" Model Evaluation on Test Set")
print("="*40)
print(f"MAE       : {mae:.2f} °C")
print(f"RMSE      : {rmse:.2f} °C")
print(f"R² Score  : {r2:.3f}")
print("="*40)

# Step 10: Reconstruct aligned test dates after sequence window
test_index_start = split_index + window
aligned_test_index = df.index[test_index_start:test_index_start + len(y_test_seq)]

# Create DataFrame with predictions
df_preds = pd.DataFrame({
    'Date': aligned_test_index,
    'Actual': y_true.flatten(),
    'Predicted': y_pred.flatten()
}).set_index('Date')

# Step 11: Plot predictions
plt.figure(figsize=(12, 6))
plt.plot(df_preds.index, df_preds['Actual'], label='Actual')
plt.plot(df_preds.index, df_preds['Predicted'], label='Predicted')
plt.title('T_mean Prediction on Test Set (GRU)')
plt.ylabel('Temperature (°C)')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.2213 - mae: 0.3429 - val_loss: 0.0702 - val_mae: 0.1996 - learning_rate: 0.0010
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0828 - mae: 0.2234 - val_loss: 0.0616 - val_mae: 0.1907 - learning_rate: 0.0010
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0701 - mae: 0.2016 - val_loss: 0.0523 - val_mae: 0.1700 - learning_rate: 0.0010
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0644 - mae: 0.1949 - val_loss: 0.0534 - val_mae: 0.1783 - learning_rate: 0.0010
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0581 - mae: 0.1835 - val_loss: 0.0444 - val_mae: 0.1591 - learning_rate: 0.0010
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0555 - mae: 0.1808 - val_loss: 0.0415 - val_mae: 0.1544 - learning_rate: 0.0010
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0550 - mae: 0.1781 - val_loss: 0.0380 - val_mae: 0.1458 - learning_rate: 0.0010
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0507 - mae: 0.1723 - val_loss: 0.0395 - val_mae: 0.1469 - learning_rate: 0.0010
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0477 - mae: 0.1667 - val_loss: 0.0365 - val_mae: 0.1445 - learning_rate: 0.0010
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0498 - mae: 0.1714 - val_loss: 0.0400 - val_mae: 0.1511 - learning_rate: 0.0010
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0492 - mae: 0.1694 - val_loss: 0.0366 - val_mae: 0.1363 - learning_rate: 0.0010
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0446 - mae: 0.1620 - val_loss: 0.0371 - val_mae: 0.1409 - learning_rate: 0.0010
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0453 - mae: 0.1641 - val_loss: 0.0352 - val_mae: 0.1387 - learning_rate: 0.0010
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0498 - mae: 0.1686 - val_loss: 0.0370 - val_mae: 0.1449 - learning_rate: 0.0010
# Epoch 15/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0495 - mae: 0.1700 - val_loss: 0.0369 - val_mae: 0.1431 - learning_rate: 0.0010
# Epoch 16/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0448 - mae: 0.1617 - val_loss: 0.0347 - val_mae: 0.1399 - learning_rate: 0.0010
# Epoch 17/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0435 - mae: 0.1600 - val_loss: 0.0353 - val_mae: 0.1410 - learning_rate: 0.0010
# Epoch 18/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0467 - mae: 0.1622 - val_loss: 0.0365 - val_mae: 0.1469 - learning_rate: 0.0010
# Epoch 19/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0428 - mae: 0.1563 - val_loss: 0.0355 - val_mae: 0.1394 - learning_rate: 0.0010
# Epoch 20/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0438 - mae: 0.1590 - val_loss: 0.0373 - val_mae: 0.1416 - learning_rate: 0.0010
# Epoch 21/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0466 - mae: 0.1660 - val_loss: 0.0359 - val_mae: 0.1411 - learning_rate: 0.0010
# Epoch 22/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0405 - mae: 0.1518 - val_loss: 0.0338 - val_mae: 0.1365 - learning_rate: 5.0000e-04
# Epoch 23/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0405 - mae: 0.1538 - val_loss: 0.0341 - val_mae: 0.1397 - learning_rate: 5.0000e-04
# Epoch 24/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0414 - mae: 0.1561 - val_loss: 0.0346 - val_mae: 0.1406 - learning_rate: 5.0000e-04
# Epoch 25/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0420 - mae: 0.1540 - val_loss: 0.0346 - val_mae: 0.1409 - learning_rate: 5.0000e-04
# Epoch 26/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0367 - mae: 0.1458 - val_loss: 0.0375 - val_mae: 0.1484 - learning_rate: 5.0000e-04
# Epoch 27/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0400 - mae: 0.1509 - val_loss: 0.0351 - val_mae: 0.1402 - learning_rate: 5.0000e-04
# Epoch 28/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0391 - mae: 0.1483 - val_loss: 0.0335 - val_mae: 0.1382 - learning_rate: 2.5000e-04
# Epoch 29/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0399 - mae: 0.1508 - val_loss: 0.0350 - val_mae: 0.1414 - learning_rate: 2.5000e-04
# Epoch 30/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0364 - mae: 0.1464 - val_loss: 0.0349 - val_mae: 0.1420 - learning_rate: 2.5000e-04
# Epoch 31/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0392 - mae: 0.1482 - val_loss: 0.0331 - val_mae: 0.1332 - learning_rate: 2.5000e-04
# Epoch 32/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0378 - mae: 0.1494 - val_loss: 0.0336 - val_mae: 0.1352 - learning_rate: 2.5000e-04
# Epoch 33/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0375 - mae: 0.1467 - val_loss: 0.0329 - val_mae: 0.1350 - learning_rate: 2.5000e-04
# Epoch 34/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0386 - mae: 0.1481 - val_loss: 0.0341 - val_mae: 0.1353 - learning_rate: 2.5000e-04
# Epoch 35/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0398 - mae: 0.1517 - val_loss: 0.0352 - val_mae: 0.1417 - learning_rate: 2.5000e-04
# Epoch 36/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0378 - mae: 0.1472 - val_loss: 0.0361 - val_mae: 0.1439 - learning_rate: 2.5000e-04
# Epoch 37/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0349 - mae: 0.1437 - val_loss: 0.0359 - val_mae: 0.1440 - learning_rate: 2.5000e-04
# Epoch 38/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0370 - mae: 0.1481 - val_loss: 0.0339 - val_mae: 0.1391 - learning_rate: 2.5000e-04
# Epoch 39/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0365 - mae: 0.1457 - val_loss: 0.0332 - val_mae: 0.1348 - learning_rate: 1.2500e-04
# Epoch 40/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0378 - mae: 0.1476 - val_loss: 0.0343 - val_mae: 0.1378 - learning_rate: 1.2500e-04
# Epoch 41/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0375 - mae: 0.1457 - val_loss: 0.0338 - val_mae: 0.1364 - learning_rate: 1.2500e-04
# Epoch 42/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0381 - mae: 0.1461 - val_loss: 0.0334 - val_mae: 0.1361 - learning_rate: 1.2500e-04
# Epoch 43/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0372 - mae: 0.1480 - val_loss: 0.0343 - val_mae: 0.1392 - learning_rate: 1.2500e-04
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ========================================
#  Model Evaluation on Test Set
# ========================================
# MAE       : 1.01 °C
# RMSE      : 1.36 °C
# R² Score  : 0.963
# ========================================
